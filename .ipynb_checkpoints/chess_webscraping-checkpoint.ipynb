# %%
import unittest
import time
import sys
import traceback
import requests

from console_progressbar import ProgressBar
from bs4 import BeautifulSoup
from lxml import etree

#test
def load_chess_players():
    try:
        file = open("chessplayer.txt","a")
        BASE_URL = "https://www.chessgames.com" 
        cnt = 1
        players = [] 
    
        time.sleep(3)
        tic = time.perf_counter()
        link = BASE_URL
        reps = requests.get(link)
        toc = time.perf_counter()
            
        #leer el contenido de la pagina
        html = reps.content
        if (html):  
            soup = BeautifulSoup(html,'html.parser')
            plyer_select = soup.find("select",attrs={"name":"pid"})
            options = plyer_select.find_all("option")
            for x in options:
                #print(x['value'] +' '+ x.text)
                if (x['value']):
                    file.append('code':x['value'],'name':x.text)
                    #players.append({'code':x['value'],'name':x.text})
 
         
    except ValueError:
            print(f"Error de Valor :{link}")
           # return games                     
            traceback.print_exception(*sys.exc_info())
    except:    
            print(f"Error general :{link}") 
            #return games 
            traceback.print_exception(*sys.exc_info())  

def list_chess_game(param):
    try:
        BASE_URL = "https://www.chessgames.com"
        year=param['year']
        playercomp=param['playercomp']
        pid=param['pid']
        result=param['result']
        link = f"{BASE_URL}/perl/chess.pl?yearcomp=exactly&year={year}&playercomp={playercomp}&pid={pid}&result={result}"
        cnt = 1
        games = [] 
    
        time.sleep(3)
        tic = time.perf_counter()
        reps = requests.get(link)
        toc = time.perf_counter()
            
        #leer el contenido de la pagina
        html = reps.content
        if (html):  
            soup = BeautifulSoup(html,'html.parser')
            tbs_parent = soup.find_all("table")
            tbs_child  = tbs_parent[1].find_all("table")
            rows   = tbs_child[1].find_all('tr')
            for row in rows:
                cols = row.find_all('td')
                alla  = cols[0].find_all('a')
                for a in alla:
                    games.append(f"{BASE_URL}{a.attrs.get('href')}")
                                     
        return games          
    except ValueError:
            #print(f"Error de Valor :{link}")
            #traceback.print_exception(*sys.exc_info())
            return games    
    except:    
            #print(f"Error general :{link}") 
            #traceback.print_exception(*sys.exc_info())
            return games    

def Load_write_game(link):
    
    #logging.basicConfig(filename='example.log', encoding='utf-8', level=logging.DEBUG)
    try:
       #carga el archivo de los datos
        file = open("chess_game.txt","a")
        gid = 1000000
        cnt = 1
        pgns = []
        
        # cargar la pagina
        time.sleep(3)
        tic = time.perf_counter()
        reps = requests.get(link)
        toc = time.perf_counter()
            
        #leer el contenido de la pagina
        html = reps.content
        if (html):  
            #loggin.info(f"Process {toc - tic+1:0.4} seconds url: {link}")
            soup = BeautifulSoup(html,'html.parser')
            olga_data = soup.find_all("div", attrs={"id":"olga-data"})
            
            #Carga data
            if (olga_data): 
               pgn = olga_data[0].attrs.get('pgn')
               line = pgn.replace('\n',' ').replace('\r',' ')+'\n'
               file.write(line) 
            else :
              print("Error de contenido")

        file.close()    
    except ValueError:
            file.close()
            print("Error de Valor")
            traceback.print_exception(*sys.exc_info())
    except:    
            file.close()
            print("Error de general") 
            traceback.print_exception(*sys.exc_info())
#1475
'''
pyc = 1
rango_year  = range(2019,2021 + 1)
rango_color = [{'color':'white','result':'1-0'},{'color':'black','result':'0-1'}]

for year in rango_year:
    for cl_res in rango_color:       
        pt    = 1      
        param = {'year':str(year),'playercomp':cl_res['color'],'pid':'52948','result':cl_res['result']}                                 
        gameslinks = list_chess_game(param)
        cnt   = len(gameslinks)
        message = f"DOWL {str(year)} {cl_res['color']} {cl_res['result']}"
        pb = ProgressBar(total=cnt,prefix= message, suffix=' ',decimals=2,length=50,fill='▐',zfill=' ')
        for game in gameslinks:
            #print(game)  
            Load_write_game(game)
            pb.print_progress_bar(pt)
            pt = pt + 1
'''
#print(gameslinks)                   
#print("Proceso finalizado")

print(list_chess_players())
# Out:
# [{'code': '10900', 'name': 'Adams'}, {'code': '117280', 'name': 'Adhiban'}, {'code': '14589', 'name': 'Adorjan'}, {'code': '51148', 'name': 'Akobian'}, {'code': '14125', 'name': 'Akopian'}, {'code': '10240', 'name': 'Alekhine'}, {'code': '17278', 'name': 'Aleksandrov'}, {'code': '117648', 'name': 'Alekseenko'}, {'code': '68679', 'name': 'Alekseev'}, {'code': '14210', 'name': 'Almasi'}, {'code': '87335', 'name': 'Amin'}, {'code': '50168', 'name': 'Amonatov'}, {'code': '12088', 'name': 'Anand'}, {'code': '10342', 'name': 'Anderssen'}, {'code': '12112', 'name': 'Andersson'}, {'code': '49702', 'name': 'Andreikin'}, {'code': '131813', 'name': 'Anton Guijarro'}, {'code': '10862', 'name': 'Areshchenko'}, {'code': '17316', 'name': 'Aronian'}, {'code': '137614', 'name': 'Artemiev'}, {'code': '18270', 'name': 'Avrukh'}, {'code': '17281', 'name': 'Azarov'}, {'code': '14175', 'name': 'Azmaiparashvili'}, {'code': '56835', 'name': 'Bachmann'}, {'code': '29565', 'name': 'Bacrot'}, {'code': '64696', 'name': 'Baklan'}, {'code': '16914', 'name': 'Balashov'}, {'code': '52611', 'name': 'Balogh'}, {'code': '16299', 'name': 'Bareev'}, {'code': '54619', 'name': 'Bartel'}, {'code': '65385', 'name': 'Bauer'}, {'code': '13755', 'name': 'Beliavsky'}, {'code': '42951', 'name': 'Benjamin, Joel'}, {'code': '14726', 'name': 'Benko'}, {'code': '49184', 'name': 'Berkes'}, {'code': '10429', 'name': 'Blackburne'}, {'code': '10113', 'name': 'Blatny'}, {'code': '10614', 'name': 'Bogoljubov'}, {'code': '14216', 'name': 'Bologan'}, {'code': '89113', 'name': 'Bonelli, Iturrizaga'}, {'code': '11207', 'name': 'Botvinnik'}, {'code': '16521', 'name': 'Bronstein'}, {'code': '16174', 'name': 'Browne'}, {'code': '49084', 'name': 'Bruzon Batista'}, {'code': '10762', 'name': 'Bu Xiangzhi'}, {'code': '47544', 'name': 'Capablanca'}, {'code': '52948', 'name': 'Carlsen'}, {'code': '76172', 'name': 'Caruana'}, {'code': '53011', 'name': 'Chanda'}, {'code': '11788', 'name': 'Chandler'}, {'code': '98398', 'name': 'Chao, Li'}, {'code': '10930', 'name': 'Cheparinov'}, {'code': '16894', 'name': 'Chiburdanidze'}, {'code': '10016', 'name': 'Chigorin'}, {'code': '15040', 'name': 'Christiansen'}, {'code': '109850', 'name': 'Cori'}, {'code': '14280', 'name': 'Cramling'}, {'code': '16101', 'name': 'Day'}, {'code': '15656', 'name': 'de Firmian'}, {'code': '20994', 'name': 'Delchev'}, {'code': '101982', 'name': 'Demchenko'}, {'code': '49080', 'name': 'Dominguez'}, {'code': '129292', 'name': 'Donchenko'}, {'code': '14765', 'name': 'Donner, J H'}, {'code': '12136', 'name': 'Dreev'}, {'code': '113399', 'name': 'Dubov'}, {'code': '126603', 'name': 'Duda'}, {'code': '50064', 'name': 'Dzagnidze'}, {'code': '95988', 'name': 'Edouard'}, {'code': '49257', 'name': 'Efimenko'}, {'code': '10065', 'name': 'Ehlvest'}, {'code': '49456', 'name': 'Eljanov'}, {'code': '11675', 'name': 'Epishin'}, {'code': '56768', 'name': 'Erdos'}, {'code': '138628', 'name': 'Esipenko'}, {'code': '10706', 'name': 'Euwe'}, {'code': '38807', 'name': 'Fedorchuk'}, {'code': '10754', 'name': 'Fedorov'}, {'code': '14905', 'name': 'Fedorowicz'}, {'code': '108200', 'name': 'Fedoseev'}, {'code': '95862', 'name': 'Feller'}, {'code': '18940', 'name': 'Filip'}, {'code': '20102', 'name': 'Fine'}, {'code': '152702', 'name': 'Firouzja'}, {'code': '19233', 'name': 'Fischer'}, {'code': '20071', 'name': 'Flohr'}, {'code': '28654', 'name': 'Fressinet'}, {'code': '42773', 'name': 'Fridman'}, {'code': '17586', 'name': 'Ftacnik'}, {'code': '54613', 'name': 'Gajewski'}, {'code': '49536', 'name': 'Ganguly'}, {'code': '56780', 'name': 'Gareyev'}, {'code': '54602', 'name': 'Gashimov'}, {'code': '13847', 'name': 'Gelfand'}, {'code': '15712', 'name': 'Geller'}, {'code': '47071', 'name': 'Georgiev'}, {'code': '49243', 'name': 'Ghaem Maghami'}, {'code': '23006', 'name': 'Gheorghiu'}, {'code': '107252', 'name': 'Giri'}, {'code': '15140', 'name': 'Glek'}, {'code': '15349', 'name': 'Gligoric'}, {'code': '49734', 'name': 'Grachev'}, {'code': '49248', 'name': 'G ...
